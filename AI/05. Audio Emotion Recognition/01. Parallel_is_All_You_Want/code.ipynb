# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = 'audio/Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)
        
        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]
        
        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0: 
            gender = 'female' 
        else: 
            gender = 'male'
            
        # get waveform from the sample
        waveform = get_waveforms(file)
        
        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict 
        
        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
        
    return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise
#
# ### 필요성
# - 데이터 세트가 작아 과적합 위험이 있음.
# - 오디오 신호에 백색 잡음을 추가하여 train 데이터에 존재하는 무작위 마스킹
#     - 뿐만 아니라, **유사 새 훈련 샘플 생성**
# - **잡음 영향 상쇄**
# - RAVDESS 데이터셋은 잡음이 없어 실제 데이터처럼 잡음을 추가해야 훈련이 잘 될 가능성이 있음.
#
# ### AWGN
# - **노이즈 벡터가 정규 분포에서 샘플링 되고 시간 평균이 0이기 때문에 가우시안**
# - **화이트닝 변환 후 노이즈가 발생하기 때문에 white**
# - **주파수 분포에 걸쳐 균일하게 전력 추가**
# - **실제 데이터가 아닌 훈련 데이터에만 추가 해야 함.**
#
# - 주요 매개변수는 잡음의 크기를 정의하는 **SNR(신호 대 잡음비)**
# - AWGN을 최소값으로 매개변수화하고 SNR을 최대화하여 샘플의 파형을 증가시키는 데 사용할 임의의 SNR 선택
#
# - 가우시안 노이즈(np.random.normal)의 zero-mean 벡터를 만든다.
# - whitening transformation 수행
#     - 알려진 공분산 행렬이 있는 임의의 일반(가우시안) 변수 벡터를 가져와서 공분산이 단위 행렬인 새 벡터에 매핑
#     - variance == stdev == 1 정의
#     - 벡터를 백색잡음 벡터로 변환
# - 각각 1440개의 샘플이 있는 2개의 동일한 무작위 노이즈 데이터 세트를 추가

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set 
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# ## Ready 4D arrays
# - for using 2D CNN filters

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling
# - 수렴하는 데 까지 시간을 감소시킴.
# - Standard Scaling은 대상 분포를 모를 때 합리적

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ### 일일히 불러오는 것보다 numpy로 저장시켜서 불러오는 게 계산 상 훨씬 빠름

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}') 

"""
(4320, 1, 40, 282)
- 4320 : num. samples
- 1 : channel(흑백)
- 40 : mel pitch ranges, MFC 계수
- 282 : time stamp
"""
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)
# '\n(4320, 1, 40, 282)\n- 4320 : num. samples\n- 1 : channel(흑백)\n- 40 : mel pitch ranges, MFC 계수\n- 282 : time stamp\n'

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %% [markdown]
# ### Analyzing The Flow of Tensors Through the Network
#
# **In (N,C,H,W) format, for MFCCs H = MFCC (pitch), W = time step.**
#
# **Complete flow through each convolutional block (C,H,W):**
#
#     - Layer 1 ---> 1x40x282 --> PAD-1 --> 1x42x284 --> FILTER 1x3x3 --> 16x40x282 --> MAXPOOL 2x2 stride 2 --> 16x20x141
#
#     - Layer 2 ---> 16x20x141 --> PAD-1 --> 16x22x143 --> FILTER 16x3x3 --> 32x20x141 --> MAXPOOL 4x4 stride 4 --> 32x5x35
#
#     - Layer 3 ---> 32x5x35 --> PAD-1 --> 32x7x37 --> FILTER 32x3x3 --> 64x5x35 --> MAXPOOL 4x4 stride 4 --> 64x1x8
#
#     - Flatten ---> 64x1x8 --> Final convolutional embedding length 512 1D array
#
#
# **Complete flow through transformer encoder block (C,H,W):**
#
#     - Maxpool 1x4 stride 1x4 ---> 1x40x282 --> 1x20x70
#
#     - Drop channel ---> 1x20x70 --> 20x70 (H,W)
#
#     - Change dims ---> 20x70 --> 70x40 (W,H)
#
#     - 4 x Transformer encoder ---> 70x40 --> 2x40 (W,H)
#
#     - Time average ---> 2x40 --> 1x40 --> Final transformer embedding length 40 1D array
#
#
# **FC Linear network (C,H,W):**
#
#     - Concatenate ---> 512+512+40 --> 1064
#
#     - FC Linear layer ---> 1064 --> Final linear logits output length 8 1D array
#
#     - Softmax layer: 8 ----> 1 predicted emotion / max probability class

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
summary(model, input_size=(1,40,282))
# Out:
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─MaxPool2d: 1-1                              --
# ├─TransformerEncoder: 1-2                     --
# |    └─ModuleList: 2-1                        --
# |    |    └─TransformerEncoderLayer: 3-1      48,232
# |    |    └─TransformerEncoderLayer: 3-2      48,232
# |    |    └─TransformerEncoderLayer: 3-3      48,232
# |    |    └─TransformerEncoderLayer: 3-4      48,232
# ├─Sequential: 1-3                             --
# |    └─Conv2d: 2-2                            160
# |    └─BatchNorm2d: 2-3                       32
# |    └─ReLU: 2-4                              --
# |    └─MaxPool2d: 2-5                         --
# |    └─Dropout: 2-6                           --
# |    └─Conv2d: 2-7                            4,640
# |    └─BatchNorm2d: 2-8                       64
# |    └─ReLU: 2-9                              --
# |    └─MaxPool2d: 2-10                        --
# |    └─Dropout: 2-11                          --
# |    └─Conv2d: 2-12                           18,496
# |    └─BatchNorm2d: 2-13                      128
# |    └─ReLU: 2-14                             --
# |    └─MaxPool2d: 2-15                        --
# |    └─Dropout: 2-16                          --
# ├─Sequential: 1-4                             --
# |    └─Conv2d: 2-17                           160
# |    └─BatchNorm2d: 2-18                      32
# |    └─ReLU: 2-19                             --
# |    └─MaxPool2d: 2-20                        --
# |    └─Dropout: 2-21                          --
# |    └─Conv2d: 2-22                           4,640
# |    └─BatchNorm2d: 2-23                      64
# |    └─ReLU: 2-24                             --
# |    └─MaxPool2d: 2-25                        --
# |    └─Dropout: 2-26                          --
# |    └─Conv2d: 2-27                           18,496
# |    └─BatchNorm2d: 2-28                      128
# |    └─ReLU: 2-29                             --
# |    └─MaxPool2d: 2-30                        --
# |    └─Dropout: 2-31                          --
# ├─Linear: 1-5                                 8,520
# ├─Softmax: 1-6                                --
# ======================================================================
# Total params: 248,488
# Trainable params: 248,488
# Non-trainable params: 0
# ======================================================================
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─MaxPool2d: 1-1                              --
# ├─TransformerEncoder: 1-2                     --
# |    └─ModuleList: 2-1                        --
# |    |    └─TransformerEncoderLayer: 3-1      48,232
# |    |    └─TransformerEncoderLayer: 3-2      48,232
# |    |    └─TransformerEncoderLayer: 3-3      48,232
# |    |    └─TransformerEncoderLayer: 3-4      48,232
# ├─Sequential: 1-3                             --
# |    └─Conv2d: 2-2                            160
# |    └─BatchNorm2d: 2-3                       32
# |    └─ReLU: 2-4                              --
# |    └─MaxPool2d: 2-5                         --
# |    └─Dropout: 2-6                           --
# |    └─Conv2d: 2-7                            4,640
# |    └─BatchNorm2d: 2-8                       64
# |    └─ReLU: 2-9                              --
# |    └─MaxPool2d: 2-10                        --
# |    └─Dropout: 2-11                          --
# |    └─Conv2d: 2-12                           18,496
# |    └─BatchNorm2d: 2-13                      128
# |    └─ReLU: 2-14                             --
# |    └─MaxPool2d: 2-15                        --
# |    └─Dropout: 2-16                          --
# ├─Sequential: 1-4                             --
# |    └─Conv2d: 2-17                           160
# |    └─BatchNorm2d: 2-18                      32
# |    └─ReLU: 2-19                             --
# |    └─MaxPool2d: 2-20                        --
# |    └─Dropout: 2-21                          --
# |    └─Conv2d: 2-22                           4,640
# |    └─BatchNorm2d: 2-23                      64
# |    └─ReLU: 2-24                             --
# |    └─MaxPool2d: 2-25                        --
# |    └─Dropout: 2-26                          --
# |    └─Conv2d: 2-27                           18,496
# |    └─BatchNorm2d: 2-28                      128
# |    └─ReLU: 2-29                             --
# |    └─MaxPool2d: 2-30                        --
# |    └─Dropout: 2-31                          --
# ├─Linear: 1-5                                 8,520
# ├─Softmax: 1-6                                --
# ======================================================================
# Total params: 248,488
# Trainable params: 248,488
# Non-trainable params: 0
# ======================================================================

# %%
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

optimizer = torch.optim.SGD(model.parameters(),lr=0.001, weight_decay=1e-4, momentum=0.9)

# %%
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []
# Out:
# cuda selected
# Number of trainable params:  248488

# %%
# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        checkpoint_filename = './models/checkpoints/parallel_all_you_want-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 106/107
# Epoch 0 --- loss:3.237, Epoch accuracy:27.06%, Validation loss:1.947, Validation accuracy:28.21%
# Epoch 1: iteration 106/107
# Epoch 1 --- loss:1.617, Epoch accuracy:37.87%, Validation loss:1.682, Validation accuracy:40.56%
# Epoch 2: iteration 106/107
# Epoch 2 --- loss:1.499, Epoch accuracy:43.30%, Validation loss:1.638, Validation accuracy:41.03%
# Epoch 3: iteration 106/107
# Epoch 3 --- loss:1.400, Epoch accuracy:46.21%, Validation loss:1.398, Validation accuracy:50.35%
# Epoch 4: iteration 106/107
# Epoch 4 --- loss:1.293, Epoch accuracy:51.55%, Validation loss:1.470, Validation accuracy:47.09%
# Epoch 5: iteration 106/107
# Epoch 5 --- loss:1.212, Epoch accuracy:54.40%, Validation loss:1.413, Validation accuracy:47.55%
# Epoch 6: iteration 106/107
# Epoch 6 --- loss:1.153, Epoch accuracy:57.54%, Validation loss:1.382, Validation accuracy:49.42%
# Epoch 7: iteration 106/107
# Epoch 7 --- loss:1.082, Epoch accuracy:59.02%, Validation loss:1.285, Validation accuracy:51.52%
# Epoch 8: iteration 106/107
# Epoch 8 --- loss:1.019, Epoch accuracy:61.49%, Validation loss:1.302, Validation accuracy:51.28%
# Epoch 9: iteration 106/107
# Epoch 9 --- loss:0.966, Epoch accuracy:63.53%, Validation loss:1.412, Validation accuracy:52.45%
# Epoch 10: iteration 106/107
# Epoch 10 --- loss:0.882, Epoch accuracy:67.22%, Validation loss:1.318, Validation accuracy:54.78%
# Epoch 11: iteration 106/107
# Epoch 11 --- loss:0.810, Epoch accuracy:70.12%, Validation loss:1.473, Validation accuracy:50.35%
# Epoch 12: iteration 106/107
# Epoch 12 --- loss:0.772, Epoch accuracy:70.42%, Validation loss:1.376, Validation accuracy:55.71%
# Epoch 13: iteration 106/107
# Epoch 13 --- loss:0.722, Epoch accuracy:73.29%, Validation loss:1.338, Validation accuracy:56.18%
# Epoch 14: iteration 106/107
# Epoch 14 --- loss:0.680, Epoch accuracy:74.60%, Validation loss:1.270, Validation accuracy:60.14%
# Epoch 15: iteration 106/107
# Epoch 15 --- loss:0.641, Epoch accuracy:76.49%, Validation loss:1.406, Validation accuracy:56.88%
# Epoch 16: iteration 106/107
# Epoch 16 --- loss:0.578, Epoch accuracy:78.52%, Validation loss:1.387, Validation accuracy:56.18%
# Epoch 17: iteration 106/107
# Epoch 17 --- loss:0.568, Epoch accuracy:79.51%, Validation loss:1.289, Validation accuracy:60.14%
# Epoch 18: iteration 106/107
# Epoch 18 --- loss:0.538, Epoch accuracy:80.38%, Validation loss:1.405, Validation accuracy:60.84%
# Epoch 19: iteration 106/107
# Epoch 19 --- loss:0.505, Epoch accuracy:81.75%, Validation loss:1.543, Validation accuracy:53.15%
# Epoch 20: iteration 106/107
# Epoch 20 --- loss:0.467, Epoch accuracy:82.53%, Validation loss:1.348, Validation accuracy:58.28%
# Epoch 21: iteration 106/107
# Epoch 21 --- loss:0.457, Epoch accuracy:82.85%, Validation loss:1.529, Validation accuracy:55.24%
# Epoch 22: iteration 106/107
# Epoch 22 --- loss:0.439, Epoch accuracy:83.03%, Validation loss:1.458, Validation accuracy:55.71%
# Epoch 23: iteration 106/107
# Epoch 23 --- loss:0.426, Epoch accuracy:83.84%, Validation loss:1.472, Validation accuracy:57.81%
# Epoch 24: iteration 106/107
# Epoch 24 --- loss:0.372, Epoch accuracy:86.40%, Validation loss:1.482, Validation accuracy:59.44%
# Epoch 25: iteration 106/107
# Epoch 25 --- loss:0.408, Epoch accuracy:84.57%, Validation loss:1.528, Validation accuracy:57.58%
# Epoch 26: iteration 106/107
# Epoch 26 --- loss:0.347, Epoch accuracy:86.75%, Validation loss:1.688, Validation accuracy:58.04%
# Epoch 27: iteration 106/107
# Epoch 27 --- loss:0.338, Epoch accuracy:87.77%, Validation loss:1.567, Validation accuracy:56.88%
# Epoch 28: iteration 106/107
# Epoch 28 --- loss:0.303, Epoch accuracy:88.84%, Validation loss:1.617, Validation accuracy:55.01%
# Epoch 29: iteration 106/107
# Epoch 29 --- loss:0.315, Epoch accuracy:88.23%, Validation loss:1.653, Validation accuracy:55.94%
# Epoch 30: iteration 106/107
# Epoch 30 --- loss:0.302, Epoch accuracy:89.13%, Validation loss:1.638, Validation accuracy:57.34%
# Epoch 31: iteration 106/107
# Epoch 31 --- loss:0.262, Epoch accuracy:90.73%, Validation loss:1.664, Validation accuracy:56.64%
# Epoch 32: iteration 106/107
# Epoch 32 --- loss:0.250, Epoch accuracy:90.67%, Validation loss:1.733, Validation accuracy:56.88%
# Epoch 33: iteration 106/107
# Epoch 33 --- loss:0.256, Epoch accuracy:90.76%, Validation loss:1.757, Validation accuracy:55.01%
# Epoch 34: iteration 106/107
# Epoch 34 --- loss:0.241, Epoch accuracy:90.50%, Validation loss:1.514, Validation accuracy:58.74%
# Epoch 35: iteration 106/107
# Epoch 35 --- loss:0.234, Epoch accuracy:91.54%, Validation loss:1.817, Validation accuracy:55.48%
# Epoch 36: iteration 106/107
# Epoch 36 --- loss:0.207, Epoch accuracy:92.53%, Validation loss:1.620, Validation accuracy:61.54%
# Epoch 37: iteration 106/107
# Epoch 37 --- loss:0.201, Epoch accuracy:92.68%, Validation loss:1.663, Validation accuracy:58.51%
# Epoch 38: iteration 106/107
# Epoch 38 --- loss:0.196, Epoch accuracy:92.79%, Validation loss:1.796, Validation accuracy:57.81%
# Epoch 39: iteration 106/107
# Epoch 39 --- loss:0.225, Epoch accuracy:91.54%, Validation loss:1.732, Validation accuracy:60.84%
# Epoch 40: iteration 106/107
# Epoch 40 --- loss:0.186, Epoch accuracy:93.29%, Validation loss:1.669, Validation accuracy:58.51%
# Epoch 41: iteration 106/107
# Epoch 41 --- loss:0.191, Epoch accuracy:92.94%, Validation loss:1.691, Validation accuracy:58.04%
# Epoch 42: iteration 106/107
# Epoch 42 --- loss:0.168, Epoch accuracy:93.96%, Validation loss:1.678, Validation accuracy:59.67%
# Epoch 43: iteration 106/107
# Epoch 43 --- loss:0.161, Epoch accuracy:94.22%, Validation loss:1.722, Validation accuracy:59.44%
# Epoch 44: iteration 106/107
# Epoch 44 --- loss:0.154, Epoch accuracy:94.80%, Validation loss:1.808, Validation accuracy:56.64%
# Epoch 45: iteration 106/107
# Epoch 45 --- loss:0.145, Epoch accuracy:94.86%, Validation loss:1.923, Validation accuracy:58.74%
# Epoch 46: iteration 106/107
# Epoch 46 --- loss:0.145, Epoch accuracy:94.62%, Validation loss:1.692, Validation accuracy:61.31%
# Epoch 47: iteration 106/107
# Epoch 47 --- loss:0.131, Epoch accuracy:95.38%, Validation loss:1.654, Validation accuracy:63.87%
# Epoch 48: iteration 106/107
# Epoch 48 --- loss:0.125, Epoch accuracy:95.96%, Validation loss:1.823, Validation accuracy:60.14%
# Epoch 49: iteration 106/107
# Epoch 49 --- loss:0.142, Epoch accuracy:94.83%, Validation loss:1.869, Validation accuracy:57.11%
# Epoch 50: iteration 106/107
# Epoch 50 --- loss:0.169, Epoch accuracy:93.61%, Validation loss:1.799, Validation accuracy:58.04%
# Epoch 51: iteration 106/107
# Epoch 51 --- loss:0.150, Epoch accuracy:94.45%, Validation loss:1.578, Validation accuracy:61.77%
# Epoch 52: iteration 106/107
# Epoch 52 --- loss:0.123, Epoch accuracy:95.82%, Validation loss:1.691, Validation accuracy:61.77%
# Epoch 53: iteration 106/107
# Epoch 53 --- loss:0.122, Epoch accuracy:95.44%, Validation loss:1.789, Validation accuracy:60.37%
# Epoch 54: iteration 106/107
# Epoch 54 --- loss:0.120, Epoch accuracy:95.84%, Validation loss:1.782, Validation accuracy:59.91%
# Epoch 55: iteration 106/107
# Epoch 55 --- loss:0.098, Epoch accuracy:96.45%, Validation loss:1.728, Validation accuracy:59.44%
# Epoch 56: iteration 106/107
# Epoch 56 --- loss:0.115, Epoch accuracy:95.90%, Validation loss:1.855, Validation accuracy:59.44%
# Epoch 57: iteration 106/107
# Epoch 57 --- loss:0.120, Epoch accuracy:95.61%, Validation loss:1.912, Validation accuracy:57.58%
# Epoch 58: iteration 106/107
# Epoch 58 --- loss:0.130, Epoch accuracy:95.12%, Validation loss:1.682, Validation accuracy:58.28%
# Epoch 59: iteration 106/107
# Epoch 59 --- loss:0.124, Epoch accuracy:95.23%, Validation loss:1.756, Validation accuracy:61.54%
# Epoch 60: iteration 106/107
# Epoch 60 --- loss:0.107, Epoch accuracy:96.05%, Validation loss:1.842, Validation accuracy:60.14%
# Epoch 61: iteration 106/107
# Epoch 61 --- loss:0.093, Epoch accuracy:96.83%, Validation loss:1.811, Validation accuracy:58.97%
# Epoch 62: iteration 106/107
# Epoch 62 --- loss:0.094, Epoch accuracy:96.28%, Validation loss:1.796, Validation accuracy:58.97%
# Epoch 63: iteration 106/107
# Epoch 63 --- loss:0.072, Epoch accuracy:97.36%, Validation loss:1.785, Validation accuracy:59.44%
# Epoch 64: iteration 106/107
# Epoch 64 --- loss:0.096, Epoch accuracy:96.45%, Validation loss:1.766, Validation accuracy:58.74%
# Epoch 65: iteration 106/107
# Epoch 65 --- loss:0.095, Epoch accuracy:96.43%, Validation loss:1.986, Validation accuracy:59.67%
# Epoch 66: iteration 106/107
# Epoch 66 --- loss:0.091, Epoch accuracy:96.60%, Validation loss:1.959, Validation accuracy:55.48%
# Epoch 67: iteration 106/107
# Epoch 67 --- loss:0.080, Epoch accuracy:97.24%, Validation loss:1.796, Validation accuracy:57.81%
# Epoch 68: iteration 106/107
# Epoch 68 --- loss:0.085, Epoch accuracy:97.38%, Validation loss:1.868, Validation accuracy:62.24%
# Epoch 69: iteration 106/107
# Epoch 69 --- loss:0.067, Epoch accuracy:97.56%, Validation loss:1.772, Validation accuracy:61.07%
# Epoch 70: iteration 106/107
# Epoch 70 --- loss:0.089, Epoch accuracy:96.72%, Validation loss:1.766, Validation accuracy:58.51%
# Epoch 71: iteration 106/107
# Epoch 71 --- loss:0.074, Epoch accuracy:97.30%, Validation loss:1.715, Validation accuracy:58.97%
# Epoch 72: iteration 106/107
# Epoch 72 --- loss:0.083, Epoch accuracy:96.95%, Validation loss:1.805, Validation accuracy:60.14%
# Epoch 73: iteration 106/107
# Epoch 73 --- loss:0.072, Epoch accuracy:97.36%, Validation loss:1.683, Validation accuracy:60.37%
# Epoch 74: iteration 106/107
# Epoch 74 --- loss:0.068, Epoch accuracy:97.65%, Validation loss:1.966, Validation accuracy:59.91%
# Epoch 75: iteration 106/107
# Epoch 75 --- loss:0.070, Epoch accuracy:97.44%, Validation loss:1.754, Validation accuracy:62.94%
# Epoch 76: iteration 106/107
# Epoch 76 --- loss:0.062, Epoch accuracy:97.88%, Validation loss:1.631, Validation accuracy:63.87%
# Epoch 77: iteration 106/107
# Epoch 77 --- loss:0.069, Epoch accuracy:97.36%, Validation loss:1.733, Validation accuracy:61.07%
# Epoch 78: iteration 106/107
# Epoch 78 --- loss:0.072, Epoch accuracy:97.44%, Validation loss:1.824, Validation accuracy:58.51%
# Epoch 79: iteration 106/107
# Epoch 79 --- loss:0.066, Epoch accuracy:97.65%, Validation loss:1.802, Validation accuracy:58.74%
# Epoch 80: iteration 106/107
# Epoch 80 --- loss:0.061, Epoch accuracy:97.82%, Validation loss:1.792, Validation accuracy:57.34%
# Epoch 81: iteration 106/107
# Epoch 81 --- loss:0.061, Epoch accuracy:98.14%, Validation loss:1.779, Validation accuracy:59.67%
# Epoch 82: iteration 106/107
# Epoch 82 --- loss:0.054, Epoch accuracy:98.08%, Validation loss:1.689, Validation accuracy:62.94%
# Epoch 83: iteration 106/107
# Epoch 83 --- loss:0.061, Epoch accuracy:97.62%, Validation loss:1.691, Validation accuracy:61.07%
# Epoch 84: iteration 106/107
# Epoch 84 --- loss:0.056, Epoch accuracy:97.94%, Validation loss:1.797, Validation accuracy:58.28%
# Epoch 85: iteration 106/107
# Epoch 85 --- loss:0.043, Epoch accuracy:98.26%, Validation loss:1.739, Validation accuracy:60.84%
# Epoch 86: iteration 106/107
# Epoch 86 --- loss:0.055, Epoch accuracy:98.14%, Validation loss:1.791, Validation accuracy:63.40%
# Epoch 87: iteration 106/107
# Epoch 87 --- loss:0.050, Epoch accuracy:98.11%, Validation loss:1.849, Validation accuracy:59.67%
# Epoch 88: iteration 106/107
# Epoch 88 --- loss:0.053, Epoch accuracy:98.08%, Validation loss:1.807, Validation accuracy:59.91%
# Epoch 89: iteration 106/107
# Epoch 89 --- loss:0.059, Epoch accuracy:97.97%, Validation loss:1.736, Validation accuracy:58.97%
# Epoch 90: iteration 106/107
# Epoch 90 --- loss:0.043, Epoch accuracy:98.61%, Validation loss:1.846, Validation accuracy:58.28%
# Epoch 91: iteration 106/107
# Epoch 91 --- loss:0.059, Epoch accuracy:97.88%, Validation loss:1.819, Validation accuracy:60.14%
# Epoch 92: iteration 106/107
# Epoch 92 --- loss:0.051, Epoch accuracy:98.02%, Validation loss:1.672, Validation accuracy:62.00%
# Epoch 93: iteration 106/107
# Epoch 93 --- loss:0.056, Epoch accuracy:97.97%, Validation loss:1.885, Validation accuracy:58.51%
# Epoch 94: iteration 106/107
# Epoch 94 --- loss:0.062, Epoch accuracy:97.73%, Validation loss:1.681, Validation accuracy:62.24%
# Epoch 95: iteration 106/107
# Epoch 95 --- loss:0.065, Epoch accuracy:97.59%, Validation loss:1.772, Validation accuracy:63.64%
# Epoch 96: iteration 106/107
# Epoch 96 --- loss:0.046, Epoch accuracy:98.20%, Validation loss:1.838, Validation accuracy:59.21%
# Epoch 97: iteration 106/107
# Epoch 97 --- loss:0.053, Epoch accuracy:97.70%, Validation loss:1.969, Validation accuracy:60.37%
# Epoch 98: iteration 106/107
# Epoch 98 --- loss:0.063, Epoch accuracy:97.68%, Validation loss:1.820, Validation accuracy:58.97%
# Epoch 99: iteration 106/107
# Epoch 99 --- loss:0.048, Epoch accuracy:98.31%, Validation loss:1.831, Validation accuracy:59.67%
# Epoch 100: iteration 106/107
# Epoch 100 --- loss:0.036, Epoch accuracy:98.90%, Validation loss:1.621, Validation accuracy:62.47%
# Epoch 101: iteration 106/107
# Epoch 101 --- loss:0.037, Epoch accuracy:98.81%, Validation loss:1.846, Validation accuracy:60.84%
# Epoch 102: iteration 106/107
# Epoch 102 --- loss:0.051, Epoch accuracy:98.26%, Validation loss:1.743, Validation accuracy:61.31%
# Epoch 103: iteration 106/107
# Epoch 103 --- loss:0.043, Epoch accuracy:98.46%, Validation loss:1.955, Validation accuracy:57.58%
# Epoch 104: iteration 106/107
# Epoch 104 --- loss:0.061, Epoch accuracy:97.94%, Validation loss:1.780, Validation accuracy:62.24%
# Epoch 105: iteration 106/107
# Epoch 105 --- loss:0.047, Epoch accuracy:98.14%, Validation loss:1.826, Validation accuracy:59.44%
# Epoch 106: iteration 106/107
# Epoch 106 --- loss:0.049, Epoch accuracy:98.23%, Validation loss:1.719, Validation accuracy:60.14%
# Epoch 107: iteration 106/107
# Epoch 107 --- loss:0.046, Epoch accuracy:98.43%, Validation loss:1.890, Validation accuracy:59.67%
# Epoch 108: iteration 106/107
# Epoch 108 --- loss:0.044, Epoch accuracy:98.63%, Validation loss:1.680, Validation accuracy:61.77%
# Epoch 109: iteration 106/107
# Epoch 109 --- loss:0.037, Epoch accuracy:98.69%, Validation loss:1.875, Validation accuracy:58.97%
# Epoch 110: iteration 106/107
# Epoch 110 --- loss:0.040, Epoch accuracy:98.66%, Validation loss:1.798, Validation accuracy:61.31%
# Epoch 111: iteration 106/107
# Epoch 111 --- loss:0.039, Epoch accuracy:98.61%, Validation loss:1.775, Validation accuracy:60.14%
# Epoch 112: iteration 106/107
# Epoch 112 --- loss:0.038, Epoch accuracy:98.63%, Validation loss:1.664, Validation accuracy:60.84%
# Epoch 113: iteration 106/107
# Epoch 113 --- loss:0.039, Epoch accuracy:98.55%, Validation loss:1.741, Validation accuracy:59.21%
# Epoch 114: iteration 106/107
# Epoch 114 --- loss:0.034, Epoch accuracy:98.84%, Validation loss:1.728, Validation accuracy:62.94%
# Epoch 115: iteration 106/107
# Epoch 115 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:1.617, Validation accuracy:61.31%
# Epoch 116: iteration 106/107
# Epoch 116 --- loss:0.032, Epoch accuracy:98.92%, Validation loss:1.664, Validation accuracy:62.47%
# Epoch 117: iteration 106/107
# Epoch 117 --- loss:0.029, Epoch accuracy:98.95%, Validation loss:1.832, Validation accuracy:61.54%
# Epoch 118: iteration 106/107
# Epoch 118 --- loss:0.036, Epoch accuracy:98.66%, Validation loss:1.776, Validation accuracy:59.91%
# Epoch 119: iteration 106/107
# Epoch 119 --- loss:0.042, Epoch accuracy:98.63%, Validation loss:1.780, Validation accuracy:60.37%
# Epoch 120: iteration 106/107
# Epoch 120 --- loss:0.036, Epoch accuracy:98.78%, Validation loss:1.973, Validation accuracy:57.58%
# Epoch 121: iteration 106/107
# Epoch 121 --- loss:0.059, Epoch accuracy:97.91%, Validation loss:1.832, Validation accuracy:59.21%
# Epoch 122: iteration 106/107
# Epoch 122 --- loss:0.044, Epoch accuracy:98.34%, Validation loss:1.787, Validation accuracy:61.54%
# Epoch 123: iteration 106/107
# Epoch 123 --- loss:0.062, Epoch accuracy:97.53%, Validation loss:1.823, Validation accuracy:61.31%
# Epoch 124: iteration 106/107
# Epoch 124 --- loss:0.048, Epoch accuracy:98.31%, Validation loss:1.807, Validation accuracy:62.24%
# Epoch 125: iteration 106/107
# Epoch 125 --- loss:0.038, Epoch accuracy:98.69%, Validation loss:1.633, Validation accuracy:61.54%
# Epoch 126: iteration 106/107
# Epoch 126 --- loss:0.044, Epoch accuracy:98.17%, Validation loss:1.798, Validation accuracy:63.87%
# Epoch 127: iteration 106/107
# Epoch 127 --- loss:0.033, Epoch accuracy:98.87%, Validation loss:1.726, Validation accuracy:62.94%
# Epoch 128: iteration 106/107
# Epoch 128 --- loss:0.039, Epoch accuracy:98.46%, Validation loss:1.756, Validation accuracy:62.24%
# Epoch 129: iteration 106/107
# Epoch 129 --- loss:0.032, Epoch accuracy:98.78%, Validation loss:1.854, Validation accuracy:61.07%
# Epoch 130: iteration 106/107
# Epoch 130 --- loss:0.031, Epoch accuracy:98.90%, Validation loss:1.830, Validation accuracy:60.37%
# Epoch 131: iteration 106/107
# Epoch 131 --- loss:0.046, Epoch accuracy:98.23%, Validation loss:1.822, Validation accuracy:61.77%
# Epoch 132: iteration 106/107
# Epoch 132 --- loss:0.035, Epoch accuracy:98.72%, Validation loss:1.965, Validation accuracy:61.07%
# Epoch 133: iteration 106/107
# Epoch 133 --- loss:0.039, Epoch accuracy:98.58%, Validation loss:1.675, Validation accuracy:63.40%
# Epoch 134: iteration 106/107
# Epoch 134 --- loss:0.028, Epoch accuracy:99.07%, Validation loss:1.692, Validation accuracy:63.17%
# Epoch 135: iteration 106/107
# Epoch 135 --- loss:0.034, Epoch accuracy:98.61%, Validation loss:1.727, Validation accuracy:61.07%
# Epoch 136: iteration 106/107
# Epoch 136 --- loss:0.054, Epoch accuracy:97.91%, Validation loss:1.789, Validation accuracy:61.77%
# Epoch 137: iteration 106/107
# Epoch 137 --- loss:0.055, Epoch accuracy:97.99%, Validation loss:1.834, Validation accuracy:59.67%
# Epoch 138: iteration 106/107
# Epoch 138 --- loss:0.058, Epoch accuracy:97.82%, Validation loss:1.865, Validation accuracy:59.67%
# Epoch 139: iteration 106/107
# Epoch 139 --- loss:0.049, Epoch accuracy:98.29%, Validation loss:1.683, Validation accuracy:61.07%
# Epoch 140: iteration 106/107
# Epoch 140 --- loss:0.042, Epoch accuracy:98.43%, Validation loss:1.742, Validation accuracy:60.14%
# Epoch 141: iteration 106/107
# Epoch 141 --- loss:0.045, Epoch accuracy:98.43%, Validation loss:1.692, Validation accuracy:62.94%
# Epoch 142: iteration 106/107
# Epoch 142 --- loss:0.038, Epoch accuracy:98.61%, Validation loss:1.877, Validation accuracy:60.61%
# Epoch 143: iteration 106/107
# Epoch 143 --- loss:0.033, Epoch accuracy:98.90%, Validation loss:1.743, Validation accuracy:60.14%
# Epoch 144: iteration 106/107
# Epoch 144 --- loss:0.026, Epoch accuracy:99.19%, Validation loss:1.729, Validation accuracy:61.07%
# Epoch 145: iteration 106/107
# Epoch 145 --- loss:0.028, Epoch accuracy:99.04%, Validation loss:1.728, Validation accuracy:62.94%
# Epoch 146: iteration 106/107
# Epoch 146 --- loss:0.039, Epoch accuracy:98.49%, Validation loss:1.771, Validation accuracy:62.47%
# Epoch 147: iteration 106/107
# Epoch 147 --- loss:0.041, Epoch accuracy:98.43%, Validation loss:1.726, Validation accuracy:62.24%
# Epoch 148: iteration 106/107
# Epoch 148 --- loss:0.046, Epoch accuracy:98.23%, Validation loss:1.738, Validation accuracy:60.84%
# Epoch 149: iteration 106/107
# Epoch 149 --- loss:0.032, Epoch accuracy:98.81%, Validation loss:1.643, Validation accuracy:62.47%
# Epoch 150: iteration 106/107
# Epoch 150 --- loss:0.025, Epoch accuracy:99.22%, Validation loss:1.729, Validation accuracy:60.37%
# Epoch 151: iteration 106/107
# Epoch 151 --- loss:0.027, Epoch accuracy:99.04%, Validation loss:1.744, Validation accuracy:60.84%
# Epoch 152: iteration 106/107
# Epoch 152 --- loss:0.032, Epoch accuracy:98.81%, Validation loss:1.800, Validation accuracy:61.77%
# Epoch 153: iteration 106/107
# Epoch 153 --- loss:0.031, Epoch accuracy:98.78%, Validation loss:1.911, Validation accuracy:58.74%
# Epoch 154: iteration 106/107
# Epoch 154 --- loss:0.047, Epoch accuracy:98.29%, Validation loss:1.869, Validation accuracy:60.37%
# Epoch 155: iteration 106/107
# Epoch 155 --- loss:0.066, Epoch accuracy:97.62%, Validation loss:1.826, Validation accuracy:60.61%
# Epoch 156: iteration 106/107
# Epoch 156 --- loss:0.056, Epoch accuracy:97.82%, Validation loss:1.713, Validation accuracy:60.61%
# Epoch 157: iteration 106/107
# Epoch 157 --- loss:0.032, Epoch accuracy:98.81%, Validation loss:1.826, Validation accuracy:60.37%
# Epoch 158: iteration 106/107
# Epoch 158 --- loss:0.037, Epoch accuracy:98.58%, Validation loss:1.755, Validation accuracy:59.44%
# Epoch 159: iteration 106/107
# Epoch 159 --- loss:0.040, Epoch accuracy:98.61%, Validation loss:1.767, Validation accuracy:58.74%
# Epoch 160: iteration 106/107
# Epoch 160 --- loss:0.035, Epoch accuracy:98.72%, Validation loss:1.597, Validation accuracy:64.57%
# Epoch 161: iteration 106/107
# Epoch 161 --- loss:0.022, Epoch accuracy:99.19%, Validation loss:1.751, Validation accuracy:61.54%
# Epoch 162: iteration 106/107
# Epoch 162 --- loss:0.024, Epoch accuracy:99.16%, Validation loss:1.752, Validation accuracy:61.77%
# Epoch 163: iteration 106/107
# Epoch 163 --- loss:0.058, Epoch accuracy:97.73%, Validation loss:1.879, Validation accuracy:58.04%
# Epoch 164: iteration 106/107
# Epoch 164 --- loss:0.033, Epoch accuracy:98.84%, Validation loss:1.767, Validation accuracy:60.37%
# Epoch 165: iteration 106/107
# Epoch 165 --- loss:0.082, Epoch accuracy:96.80%, Validation loss:1.894, Validation accuracy:58.74%
# Epoch 166: iteration 106/107
# Epoch 166 --- loss:0.029, Epoch accuracy:98.90%, Validation loss:1.804, Validation accuracy:59.44%
# Epoch 167: iteration 106/107
# Epoch 167 --- loss:0.022, Epoch accuracy:99.19%, Validation loss:1.747, Validation accuracy:60.61%
# Epoch 168: iteration 106/107
# Epoch 168 --- loss:0.043, Epoch accuracy:98.43%, Validation loss:1.788, Validation accuracy:59.91%
# Epoch 169: iteration 106/107
# Epoch 169 --- loss:0.032, Epoch accuracy:98.98%, Validation loss:1.717, Validation accuracy:60.84%
# Epoch 170: iteration 106/107
# Epoch 170 --- loss:0.029, Epoch accuracy:98.90%, Validation loss:1.785, Validation accuracy:60.37%
# Epoch 171: iteration 106/107
# Epoch 171 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.660, Validation accuracy:61.77%
# Epoch 172: iteration 106/107
# Epoch 172 --- loss:0.038, Epoch accuracy:98.63%, Validation loss:1.651, Validation accuracy:61.31%
# Epoch 173: iteration 106/107
# Epoch 173 --- loss:0.050, Epoch accuracy:98.02%, Validation loss:1.694, Validation accuracy:62.00%
# Epoch 174: iteration 106/107
# Epoch 174 --- loss:0.037, Epoch accuracy:98.63%, Validation loss:1.796, Validation accuracy:59.67%
# Epoch 175: iteration 106/107
# Epoch 175 --- loss:0.048, Epoch accuracy:98.02%, Validation loss:1.815, Validation accuracy:61.07%
# Epoch 176: iteration 106/107
# Epoch 176 --- loss:0.031, Epoch accuracy:98.92%, Validation loss:1.807, Validation accuracy:58.04%
# Epoch 177: iteration 106/107
# Epoch 177 --- loss:0.019, Epoch accuracy:99.30%, Validation loss:1.787, Validation accuracy:61.77%
# Epoch 178: iteration 106/107
# Epoch 178 --- loss:0.023, Epoch accuracy:99.07%, Validation loss:1.774, Validation accuracy:61.07%
# Epoch 179: iteration 106/107
# Epoch 179 --- loss:0.028, Epoch accuracy:98.98%, Validation loss:1.712, Validation accuracy:62.94%
# Epoch 180: iteration 106/107
# Epoch 180 --- loss:0.025, Epoch accuracy:99.16%, Validation loss:1.875, Validation accuracy:59.91%
# Epoch 181: iteration 106/107
# Epoch 181 --- loss:0.041, Epoch accuracy:98.37%, Validation loss:2.064, Validation accuracy:58.28%
# Epoch 182: iteration 106/107
# Epoch 182 --- loss:0.040, Epoch accuracy:98.52%, Validation loss:1.647, Validation accuracy:60.84%
# Epoch 183: iteration 106/107
# Epoch 183 --- loss:0.042, Epoch accuracy:98.43%, Validation loss:1.761, Validation accuracy:59.91%
# Epoch 184: iteration 106/107
# Epoch 184 --- loss:0.030, Epoch accuracy:98.90%, Validation loss:1.705, Validation accuracy:62.00%
# Epoch 185: iteration 106/107
# Epoch 185 --- loss:0.036, Epoch accuracy:98.58%, Validation loss:2.088, Validation accuracy:58.74%
# Epoch 186: iteration 106/107
# Epoch 186 --- loss:0.054, Epoch accuracy:98.08%, Validation loss:1.751, Validation accuracy:59.67%
# Epoch 187: iteration 106/107
# Epoch 187 --- loss:0.054, Epoch accuracy:97.97%, Validation loss:1.837, Validation accuracy:59.21%
# Epoch 188: iteration 106/107
# Epoch 188 --- loss:0.061, Epoch accuracy:97.56%, Validation loss:1.895, Validation accuracy:58.04%
# Epoch 189: iteration 106/107
# Epoch 189 --- loss:0.023, Epoch accuracy:99.24%, Validation loss:1.743, Validation accuracy:63.64%
# Epoch 190: iteration 106/107
# Epoch 190 --- loss:0.036, Epoch accuracy:98.58%, Validation loss:1.855, Validation accuracy:59.21%
# Epoch 191: iteration 106/107
# Epoch 191 --- loss:0.023, Epoch accuracy:99.22%, Validation loss:1.807, Validation accuracy:61.54%
# Epoch 192: iteration 106/107
# Epoch 192 --- loss:0.026, Epoch accuracy:99.16%, Validation loss:1.755, Validation accuracy:59.67%
# Epoch 193: iteration 106/107
# Epoch 193 --- loss:0.030, Epoch accuracy:98.87%, Validation loss:1.991, Validation accuracy:58.04%
# Epoch 194: iteration 106/107
# Epoch 194 --- loss:0.030, Epoch accuracy:99.04%, Validation loss:1.657, Validation accuracy:60.84%
# Epoch 195: iteration 106/107
# Epoch 195 --- loss:0.021, Epoch accuracy:99.22%, Validation loss:1.871, Validation accuracy:58.51%
# Epoch 196: iteration 106/107
# Epoch 196 --- loss:0.022, Epoch accuracy:99.16%, Validation loss:1.913, Validation accuracy:59.44%
# Epoch 197: iteration 106/107
# Epoch 197 --- loss:0.028, Epoch accuracy:98.98%, Validation loss:1.776, Validation accuracy:64.10%
# Epoch 198: iteration 106/107
# Epoch 198 --- loss:0.025, Epoch accuracy:99.10%, Validation loss:1.786, Validation accuracy:61.07%
# Epoch 199: iteration 106/107
# Epoch 199 --- loss:0.026, Epoch accuracy:99.10%, Validation loss:1.722, Validation accuracy:60.61%
# Epoch 200: iteration 106/107
# Epoch 200 --- loss:0.022, Epoch accuracy:99.07%, Validation loss:1.809, Validation accuracy:59.21%
# Epoch 201: iteration 106/107
# Epoch 201 --- loss:0.029, Epoch accuracy:98.95%, Validation loss:1.702, Validation accuracy:62.47%
# Epoch 202: iteration 106/107
# Epoch 202 --- loss:0.043, Epoch accuracy:98.17%, Validation loss:1.766, Validation accuracy:60.37%
# Epoch 203: iteration 106/107
# Epoch 203 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.755, Validation accuracy:61.54%
# Epoch 204: iteration 106/107
# Epoch 204 --- loss:0.083, Epoch accuracy:96.89%, Validation loss:1.852, Validation accuracy:57.81%
# Epoch 205: iteration 106/107
# Epoch 205 --- loss:0.031, Epoch accuracy:98.98%, Validation loss:1.737, Validation accuracy:60.84%
# Epoch 206: iteration 106/107
# Epoch 206 --- loss:0.027, Epoch accuracy:98.98%, Validation loss:1.778, Validation accuracy:60.37%
# Epoch 207: iteration 106/107
# Epoch 207 --- loss:0.059, Epoch accuracy:97.53%, Validation loss:1.959, Validation accuracy:61.77%
# Epoch 208: iteration 106/107
# Epoch 208 --- loss:0.051, Epoch accuracy:98.11%, Validation loss:1.934, Validation accuracy:61.54%
# Epoch 209: iteration 106/107
# Epoch 209 --- loss:0.026, Epoch accuracy:99.13%, Validation loss:1.746, Validation accuracy:60.84%
# Epoch 210: iteration 106/107
# Epoch 210 --- loss:0.073, Epoch accuracy:96.83%, Validation loss:1.794, Validation accuracy:57.81%
# Epoch 211: iteration 106/107
# Epoch 211 --- loss:0.071, Epoch accuracy:97.41%, Validation loss:1.889, Validation accuracy:58.51%
# Epoch 212: iteration 106/107
# Epoch 212 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:1.792, Validation accuracy:62.70%
# Epoch 213: iteration 106/107
# Epoch 213 --- loss:0.045, Epoch accuracy:98.55%, Validation loss:1.703, Validation accuracy:60.37%
# Epoch 214: iteration 106/107
# Epoch 214 --- loss:0.042, Epoch accuracy:98.40%, Validation loss:1.757, Validation accuracy:62.94%
# Epoch 215: iteration 106/107
# Epoch 215 --- loss:0.030, Epoch accuracy:99.01%, Validation loss:1.750, Validation accuracy:60.37%
# Epoch 216: iteration 106/107
# Epoch 216 --- loss:0.019, Epoch accuracy:99.24%, Validation loss:1.705, Validation accuracy:61.54%
# Epoch 217: iteration 106/107
# Epoch 217 --- loss:0.020, Epoch accuracy:99.27%, Validation loss:1.664, Validation accuracy:63.64%
# Epoch 218: iteration 106/107
# Epoch 218 --- loss:0.019, Epoch accuracy:99.19%, Validation loss:1.692, Validation accuracy:62.94%
# Epoch 219: iteration 106/107
# Epoch 219 --- loss:0.025, Epoch accuracy:98.90%, Validation loss:1.724, Validation accuracy:59.91%
# Epoch 220: iteration 106/107
# Epoch 220 --- loss:0.021, Epoch accuracy:99.27%, Validation loss:1.852, Validation accuracy:61.31%
# Epoch 221: iteration 106/107
# Epoch 221 --- loss:0.040, Epoch accuracy:98.55%, Validation loss:1.909, Validation accuracy:58.74%
# Epoch 222: iteration 106/107
# Epoch 222 --- loss:0.060, Epoch accuracy:97.76%, Validation loss:1.808, Validation accuracy:62.00%
# Epoch 223: iteration 106/107
# Epoch 223 --- loss:0.060, Epoch accuracy:97.73%, Validation loss:1.976, Validation accuracy:60.84%
# Epoch 224: iteration 106/107
# Epoch 224 --- loss:0.052, Epoch accuracy:97.94%, Validation loss:1.644, Validation accuracy:63.87%
# Epoch 225: iteration 106/107
# Epoch 225 --- loss:0.036, Epoch accuracy:98.40%, Validation loss:1.675, Validation accuracy:61.31%
# Epoch 226: iteration 106/107
# Epoch 226 --- loss:0.017, Epoch accuracy:99.33%, Validation loss:1.615, Validation accuracy:62.94%
# Epoch 227: iteration 106/107
# Epoch 227 --- loss:0.038, Epoch accuracy:98.34%, Validation loss:1.923, Validation accuracy:61.07%
# Epoch 228: iteration 106/107
# Epoch 228 --- loss:0.031, Epoch accuracy:98.78%, Validation loss:1.722, Validation accuracy:62.47%
# Epoch 229: iteration 106/107
# Epoch 229 --- loss:0.028, Epoch accuracy:98.87%, Validation loss:1.712, Validation accuracy:61.31%
# Epoch 230: iteration 106/107
# Epoch 230 --- loss:0.027, Epoch accuracy:98.95%, Validation loss:1.717, Validation accuracy:64.10%
# Epoch 231: iteration 106/107
# Epoch 231 --- loss:0.040, Epoch accuracy:98.43%, Validation loss:1.861, Validation accuracy:61.31%
# Epoch 232: iteration 106/107
# Epoch 232 --- loss:0.041, Epoch accuracy:98.43%, Validation loss:1.982, Validation accuracy:57.81%
# Epoch 233: iteration 106/107
# Epoch 233 --- loss:0.051, Epoch accuracy:97.99%, Validation loss:1.820, Validation accuracy:62.47%
# Epoch 234: iteration 106/107
# Epoch 234 --- loss:0.035, Epoch accuracy:98.49%, Validation loss:1.759, Validation accuracy:61.54%
# Epoch 235: iteration 106/107
# Epoch 235 --- loss:0.061, Epoch accuracy:97.76%, Validation loss:1.917, Validation accuracy:59.44%
# Epoch 236: iteration 106/107
# Epoch 236 --- loss:0.066, Epoch accuracy:97.38%, Validation loss:1.854, Validation accuracy:58.74%
# Epoch 237: iteration 106/107
# Epoch 237 --- loss:0.083, Epoch accuracy:96.66%, Validation loss:1.817, Validation accuracy:60.84%
# Epoch 238: iteration 106/107
# Epoch 238 --- loss:0.036, Epoch accuracy:98.66%, Validation loss:1.760, Validation accuracy:60.84%
# Epoch 239: iteration 106/107
# Epoch 239 --- loss:0.030, Epoch accuracy:98.81%, Validation loss:1.801, Validation accuracy:59.44%
# Epoch 240: iteration 106/107
# Epoch 240 --- loss:0.024, Epoch accuracy:99.04%, Validation loss:1.685, Validation accuracy:62.70%
# Epoch 241: iteration 106/107
# Epoch 241 --- loss:0.021, Epoch accuracy:99.19%, Validation loss:1.686, Validation accuracy:63.64%
# Epoch 242: iteration 106/107
# Epoch 242 --- loss:0.027, Epoch accuracy:98.87%, Validation loss:1.922, Validation accuracy:60.14%
# Epoch 243: iteration 106/107
# Epoch 243 --- loss:0.047, Epoch accuracy:98.08%, Validation loss:1.795, Validation accuracy:59.67%
# Epoch 244: iteration 106/107
# Epoch 244 --- loss:0.046, Epoch accuracy:98.23%, Validation loss:1.821, Validation accuracy:61.31%
# Epoch 245: iteration 106/107
# Epoch 245 --- loss:0.048, Epoch accuracy:98.08%, Validation loss:1.825, Validation accuracy:61.54%
# Epoch 246: iteration 106/107
# Epoch 246 --- loss:0.031, Epoch accuracy:98.84%, Validation loss:1.733, Validation accuracy:61.54%
# Epoch 247: iteration 106/107
# Epoch 247 --- loss:0.041, Epoch accuracy:98.52%, Validation loss:1.698, Validation accuracy:64.80%
# Epoch 248: iteration 106/107
# Epoch 248 --- loss:0.030, Epoch accuracy:98.92%, Validation loss:1.754, Validation accuracy:61.31%
# Epoch 249: iteration 106/107
# Epoch 249 --- loss:0.034, Epoch accuracy:98.63%, Validation loss:1.687, Validation accuracy:65.50%
# Epoch 250: iteration 106/107
# Epoch 250 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:1.670, Validation accuracy:62.70%
# Epoch 251: iteration 106/107
# Epoch 251 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.717, Validation accuracy:63.17%
# Epoch 252: iteration 106/107
# Epoch 252 --- loss:0.021, Epoch accuracy:99.10%, Validation loss:1.706, Validation accuracy:60.61%
# Epoch 253: iteration 106/107
# Epoch 253 --- loss:0.025, Epoch accuracy:99.10%, Validation loss:2.022, Validation accuracy:60.37%
# Epoch 254: iteration 106/107
# Epoch 254 --- loss:0.046, Epoch accuracy:98.14%, Validation loss:1.715, Validation accuracy:60.84%
# Epoch 255: iteration 106/107
# Epoch 255 --- loss:0.055, Epoch accuracy:97.91%, Validation loss:1.872, Validation accuracy:58.28%
# Epoch 256: iteration 106/107
# Epoch 256 --- loss:0.041, Epoch accuracy:98.52%, Validation loss:1.948, Validation accuracy:60.61%
# Epoch 257: iteration 106/107
# Epoch 257 --- loss:0.040, Epoch accuracy:98.34%, Validation loss:1.873, Validation accuracy:58.97%
# Epoch 258: iteration 106/107
# Epoch 258 --- loss:0.055, Epoch accuracy:97.73%, Validation loss:1.814, Validation accuracy:58.28%
# Epoch 259: iteration 106/107
# Epoch 259 --- loss:0.048, Epoch accuracy:97.99%, Validation loss:1.791, Validation accuracy:58.28%
# Epoch 260: iteration 106/107
# Epoch 260 --- loss:0.036, Epoch accuracy:98.55%, Validation loss:1.856, Validation accuracy:58.51%
# Epoch 261: iteration 106/107
# Epoch 261 --- loss:0.039, Epoch accuracy:98.46%, Validation loss:1.866, Validation accuracy:58.04%
# Epoch 262: iteration 106/107
# Epoch 262 --- loss:0.022, Epoch accuracy:99.16%, Validation loss:1.716, Validation accuracy:64.34%
# Epoch 263: iteration 106/107
# Epoch 263 --- loss:0.013, Epoch accuracy:99.42%, Validation loss:1.747, Validation accuracy:63.64%
# Epoch 264: iteration 106/107
# Epoch 264 --- loss:0.024, Epoch accuracy:98.90%, Validation loss:1.775, Validation accuracy:62.00%
# Epoch 265: iteration 106/107
# Epoch 265 --- loss:0.029, Epoch accuracy:98.72%, Validation loss:1.773, Validation accuracy:60.61%
# Epoch 266: iteration 106/107
# Epoch 266 --- loss:0.107, Epoch accuracy:95.61%, Validation loss:1.974, Validation accuracy:58.04%
# Epoch 267: iteration 106/107
# Epoch 267 --- loss:0.050, Epoch accuracy:98.14%, Validation loss:1.914, Validation accuracy:62.00%
# Epoch 268: iteration 106/107
# Epoch 268 --- loss:0.029, Epoch accuracy:98.92%, Validation loss:1.869, Validation accuracy:60.37%
# Epoch 269: iteration 106/107
# Epoch 269 --- loss:0.048, Epoch accuracy:98.02%, Validation loss:1.870, Validation accuracy:61.07%
# Epoch 270: iteration 106/107
# Epoch 270 --- loss:0.031, Epoch accuracy:98.84%, Validation loss:1.837, Validation accuracy:62.24%
# Epoch 271: iteration 106/107
# Epoch 271 --- loss:0.027, Epoch accuracy:99.01%, Validation loss:1.962, Validation accuracy:55.24%
# Epoch 272: iteration 106/107
# Epoch 272 --- loss:0.050, Epoch accuracy:98.26%, Validation loss:1.735, Validation accuracy:62.47%
# Epoch 273: iteration 106/107
# Epoch 273 --- loss:0.026, Epoch accuracy:98.95%, Validation loss:1.801, Validation accuracy:59.21%
# Epoch 274: iteration 106/107
# Epoch 274 --- loss:0.031, Epoch accuracy:98.90%, Validation loss:1.654, Validation accuracy:62.24%
# Epoch 275: iteration 106/107
# Epoch 275 --- loss:0.028, Epoch accuracy:98.98%, Validation loss:1.717, Validation accuracy:61.54%
# Epoch 276: iteration 106/107
# Epoch 276 --- loss:0.026, Epoch accuracy:98.98%, Validation loss:1.825, Validation accuracy:62.00%
# Epoch 277: iteration 106/107
# Epoch 277 --- loss:0.023, Epoch accuracy:99.10%, Validation loss:1.708, Validation accuracy:64.34%
# Epoch 278: iteration 106/107
# Epoch 278 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:1.707, Validation accuracy:63.64%
# Epoch 279: iteration 106/107
# Epoch 279 --- loss:0.105, Epoch accuracy:96.02%, Validation loss:1.873, Validation accuracy:60.61%
# Epoch 280: iteration 106/107
# Epoch 280 --- loss:0.066, Epoch accuracy:97.21%, Validation loss:1.828, Validation accuracy:58.51%
# Epoch 281: iteration 106/107
# Epoch 281 --- loss:0.052, Epoch accuracy:97.99%, Validation loss:2.000, Validation accuracy:58.74%
# Epoch 282: iteration 106/107
# Epoch 282 --- loss:0.036, Epoch accuracy:98.55%, Validation loss:1.852, Validation accuracy:60.37%
# Epoch 283: iteration 106/107
# Epoch 283 --- loss:0.020, Epoch accuracy:99.36%, Validation loss:1.737, Validation accuracy:62.24%
# Epoch 284: iteration 106/107
# Epoch 284 --- loss:0.022, Epoch accuracy:99.16%, Validation loss:1.748, Validation accuracy:62.47%
# Epoch 285: iteration 106/107
# Epoch 285 --- loss:0.027, Epoch accuracy:98.81%, Validation loss:1.776, Validation accuracy:63.17%
# Epoch 286: iteration 106/107
# Epoch 286 --- loss:0.031, Epoch accuracy:98.81%, Validation loss:1.692, Validation accuracy:64.57%
# Epoch 287: iteration 106/107
# Epoch 287 --- loss:0.017, Epoch accuracy:99.36%, Validation loss:1.743, Validation accuracy:61.77%
# Epoch 288: iteration 106/107
# Epoch 288 --- loss:0.018, Epoch accuracy:99.24%, Validation loss:1.872, Validation accuracy:61.31%
# Epoch 289: iteration 106/107
# Epoch 289 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.841, Validation accuracy:60.37%
# Epoch 290: iteration 106/107
# Epoch 290 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:1.777, Validation accuracy:63.64%
# Epoch 291: iteration 106/107
# Epoch 291 --- loss:0.015, Epoch accuracy:99.45%, Validation loss:1.805, Validation accuracy:62.00%
# Epoch 292: iteration 106/107
# Epoch 292 --- loss:0.014, Epoch accuracy:99.45%, Validation loss:1.851, Validation accuracy:60.84%
# Epoch 293: iteration 106/107
# Epoch 293 --- loss:0.022, Epoch accuracy:99.27%, Validation loss:1.805, Validation accuracy:63.87%
# Epoch 294: iteration 106/107
# Epoch 294 --- loss:0.040, Epoch accuracy:98.37%, Validation loss:1.831, Validation accuracy:64.10%
# Epoch 295: iteration 106/107
# Epoch 295 --- loss:0.018, Epoch accuracy:99.22%, Validation loss:1.741, Validation accuracy:62.47%
# Epoch 296: iteration 106/107
# Epoch 296 --- loss:0.022, Epoch accuracy:99.13%, Validation loss:1.835, Validation accuracy:61.54%
# Epoch 297: iteration 106/107
# Epoch 297 --- loss:0.065, Epoch accuracy:97.24%, Validation loss:2.011, Validation accuracy:62.94%
# Epoch 298: iteration 106/107
# Epoch 298 --- loss:0.055, Epoch accuracy:97.68%, Validation loss:1.916, Validation accuracy:58.74%
# Epoch 299: iteration 106/107
# Epoch 299 --- loss:0.089, Epoch accuracy:96.19%, Validation loss:1.964, Validation accuracy:59.91%
# Epoch 300: iteration 106/107
# Epoch 300 --- loss:0.058, Epoch accuracy:97.91%, Validation loss:1.936, Validation accuracy:59.91%
# Epoch 301: iteration 106/107
# Epoch 301 --- loss:0.044, Epoch accuracy:98.26%, Validation loss:2.028, Validation accuracy:60.14%
# Epoch 302: iteration 106/107
# Epoch 302 --- loss:0.043, Epoch accuracy:98.40%, Validation loss:1.817, Validation accuracy:59.21%
# Epoch 303: iteration 106/107
# Epoch 303 --- loss:0.024, Epoch accuracy:99.07%, Validation loss:1.915, Validation accuracy:57.11%
# Epoch 304: iteration 106/107
# Epoch 304 --- loss:0.043, Epoch accuracy:98.20%, Validation loss:1.781, Validation accuracy:61.54%
# Epoch 305: iteration 106/107
# Epoch 305 --- loss:0.061, Epoch accuracy:97.65%, Validation loss:1.941, Validation accuracy:59.21%
# Epoch 306: iteration 106/107
# Epoch 306 --- loss:0.061, Epoch accuracy:97.68%, Validation loss:1.788, Validation accuracy:61.31%
# Epoch 307: iteration 106/107
# Epoch 307 --- loss:0.041, Epoch accuracy:98.34%, Validation loss:1.807, Validation accuracy:65.50%
# Epoch 308: iteration 106/107
# Epoch 308 --- loss:0.020, Epoch accuracy:99.19%, Validation loss:1.759, Validation accuracy:62.70%
# Epoch 309: iteration 106/107
# Epoch 309 --- loss:0.023, Epoch accuracy:99.01%, Validation loss:1.772, Validation accuracy:63.17%
# Epoch 310: iteration 106/107
# Epoch 310 --- loss:0.021, Epoch accuracy:99.19%, Validation loss:1.801, Validation accuracy:61.77%
# Epoch 311: iteration 106/107
# Epoch 311 --- loss:0.021, Epoch accuracy:99.19%, Validation loss:1.693, Validation accuracy:63.17%
# Epoch 312: iteration 106/107
# Epoch 312 --- loss:0.030, Epoch accuracy:98.75%, Validation loss:1.809, Validation accuracy:60.37%
# Epoch 313: iteration 106/107
# Epoch 313 --- loss:0.029, Epoch accuracy:98.75%, Validation loss:1.897, Validation accuracy:61.54%
# Epoch 314: iteration 106/107
# Epoch 314 --- loss:0.022, Epoch accuracy:99.10%, Validation loss:1.817, Validation accuracy:60.61%
# Epoch 315: iteration 106/107
# Epoch 315 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:2.057, Validation accuracy:56.18%
# Epoch 316: iteration 106/107
# Epoch 316 --- loss:0.016, Epoch accuracy:99.33%, Validation loss:1.763, Validation accuracy:62.47%
# Epoch 317: iteration 106/107
# Epoch 317 --- loss:0.016, Epoch accuracy:99.30%, Validation loss:1.920, Validation accuracy:60.84%
# Epoch 318: iteration 106/107
# Epoch 318 --- loss:0.013, Epoch accuracy:99.42%, Validation loss:1.801, Validation accuracy:61.07%
# Epoch 319: iteration 106/107
# Epoch 319 --- loss:0.014, Epoch accuracy:99.45%, Validation loss:1.803, Validation accuracy:64.80%
# Epoch 320: iteration 106/107
# Epoch 320 --- loss:0.014, Epoch accuracy:99.42%, Validation loss:1.783, Validation accuracy:62.47%
# Epoch 321: iteration 106/107
# Epoch 321 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.737, Validation accuracy:61.31%
# Epoch 322: iteration 106/107
# Epoch 322 --- loss:0.057, Epoch accuracy:97.53%, Validation loss:2.220, Validation accuracy:56.64%
# Epoch 323: iteration 106/107
# Epoch 323 --- loss:0.083, Epoch accuracy:97.04%, Validation loss:2.114, Validation accuracy:57.58%
# Epoch 324: iteration 106/107
# Epoch 324 --- loss:0.044, Epoch accuracy:98.46%, Validation loss:1.912, Validation accuracy:59.44%
# Epoch 325: iteration 106/107
# Epoch 325 --- loss:0.058, Epoch accuracy:97.68%, Validation loss:1.994, Validation accuracy:59.44%
# Epoch 326: iteration 106/107
# Epoch 326 --- loss:0.117, Epoch accuracy:95.41%, Validation loss:1.993, Validation accuracy:59.67%
# Epoch 327: iteration 106/107
# Epoch 327 --- loss:0.031, Epoch accuracy:98.90%, Validation loss:1.845, Validation accuracy:60.84%
# Epoch 328: iteration 106/107
# Epoch 328 --- loss:0.029, Epoch accuracy:98.84%, Validation loss:1.914, Validation accuracy:62.00%
# Epoch 329: iteration 106/107
# Epoch 329 --- loss:0.025, Epoch accuracy:99.04%, Validation loss:1.815, Validation accuracy:62.47%
# Epoch 330: iteration 106/107
# Epoch 330 --- loss:0.018, Epoch accuracy:99.27%, Validation loss:1.868, Validation accuracy:59.44%
# Epoch 331: iteration 106/107
# Epoch 331 --- loss:0.019, Epoch accuracy:99.13%, Validation loss:1.921, Validation accuracy:58.74%
# Epoch 332: iteration 106/107
# Epoch 332 --- loss:0.021, Epoch accuracy:99.01%, Validation loss:1.903, Validation accuracy:60.37%
# Epoch 333: iteration 106/107
# Epoch 333 --- loss:0.014, Epoch accuracy:99.36%, Validation loss:1.853, Validation accuracy:56.64%
# Epoch 334: iteration 106/107
# Epoch 334 --- loss:0.020, Epoch accuracy:99.16%, Validation loss:1.797, Validation accuracy:61.77%
# Epoch 335: iteration 106/107
# Epoch 335 --- loss:0.028, Epoch accuracy:98.75%, Validation loss:1.881, Validation accuracy:60.37%
# Epoch 336: iteration 106/107
# Epoch 336 --- loss:0.021, Epoch accuracy:99.04%, Validation loss:1.906, Validation accuracy:62.24%
# Epoch 337: iteration 106/107
# Epoch 337 --- loss:0.161, Epoch accuracy:93.84%, Validation loss:2.058, Validation accuracy:59.91%
# Epoch 338: iteration 106/107
# Epoch 338 --- loss:0.054, Epoch accuracy:97.91%, Validation loss:1.777, Validation accuracy:61.77%
# Epoch 339: iteration 106/107
# Epoch 339 --- loss:0.046, Epoch accuracy:98.37%, Validation loss:1.791, Validation accuracy:62.24%
# Epoch 340: iteration 106/107
# Epoch 340 --- loss:0.058, Epoch accuracy:97.68%, Validation loss:1.735, Validation accuracy:62.24%
# Epoch 341: iteration 106/107
# Epoch 341 --- loss:0.035, Epoch accuracy:98.72%, Validation loss:1.721, Validation accuracy:62.00%
# Epoch 342: iteration 106/107
# Epoch 342 --- loss:0.024, Epoch accuracy:99.13%, Validation loss:1.721, Validation accuracy:63.40%
# Epoch 343: iteration 106/107
# Epoch 343 --- loss:0.024, Epoch accuracy:99.04%, Validation loss:1.812, Validation accuracy:64.10%
# Epoch 344: iteration 106/107
# Epoch 344 --- loss:0.034, Epoch accuracy:98.78%, Validation loss:1.865, Validation accuracy:59.67%
# Epoch 345: iteration 106/107
# Epoch 345 --- loss:0.030, Epoch accuracy:98.92%, Validation loss:1.780, Validation accuracy:59.67%
# Epoch 346: iteration 106/107
# Epoch 346 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.803, Validation accuracy:60.61%
# Epoch 347: iteration 106/107
# Epoch 347 --- loss:0.014, Epoch accuracy:99.39%, Validation loss:1.751, Validation accuracy:61.07%
# Epoch 348: iteration 106/107
# Epoch 348 --- loss:0.038, Epoch accuracy:98.46%, Validation loss:1.923, Validation accuracy:58.97%
# Epoch 349: iteration 106/107
# Epoch 349 --- loss:0.046, Epoch accuracy:98.29%, Validation loss:1.854, Validation accuracy:61.54%
# Epoch 350: iteration 106/107
# Epoch 350 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.820, Validation accuracy:61.07%
# Epoch 351: iteration 106/107
# Epoch 351 --- loss:0.027, Epoch accuracy:98.81%, Validation loss:1.817, Validation accuracy:61.54%
# Epoch 352: iteration 106/107
# Epoch 352 --- loss:0.035, Epoch accuracy:98.52%, Validation loss:1.750, Validation accuracy:62.94%
# Epoch 353: iteration 106/107
# Epoch 353 --- loss:0.032, Epoch accuracy:98.52%, Validation loss:1.791, Validation accuracy:64.80%
# Epoch 354: iteration 106/107
# Epoch 354 --- loss:0.031, Epoch accuracy:98.63%, Validation loss:1.868, Validation accuracy:61.07%
# Epoch 355: iteration 106/107
# Epoch 355 --- loss:0.032, Epoch accuracy:98.75%, Validation loss:1.725, Validation accuracy:62.00%
# Epoch 356: iteration 106/107
# Epoch 356 --- loss:0.072, Epoch accuracy:96.92%, Validation loss:1.895, Validation accuracy:60.84%
# Epoch 357: iteration 106/107
# Epoch 357 --- loss:0.061, Epoch accuracy:97.62%, Validation loss:1.886, Validation accuracy:61.07%
# Epoch 358: iteration 106/107
# Epoch 358 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.731, Validation accuracy:60.37%
# Epoch 359: iteration 106/107
# Epoch 359 --- loss:0.031, Epoch accuracy:98.69%, Validation loss:1.992, Validation accuracy:59.67%
# Epoch 360: iteration 106/107
# Epoch 360 --- loss:0.030, Epoch accuracy:98.90%, Validation loss:1.864, Validation accuracy:64.34%
# Epoch 361: iteration 106/107
# Epoch 361 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:1.743, Validation accuracy:64.34%
# Epoch 362: iteration 106/107
# Epoch 362 --- loss:0.017, Epoch accuracy:99.27%, Validation loss:1.695, Validation accuracy:60.84%
# Epoch 363: iteration 106/107
# Epoch 363 --- loss:0.030, Epoch accuracy:98.75%, Validation loss:1.937, Validation accuracy:59.91%
# Epoch 364: iteration 106/107
# Epoch 364 --- loss:0.078, Epoch accuracy:97.41%, Validation loss:2.128, Validation accuracy:54.55%
# Epoch 365: iteration 106/107
# Epoch 365 --- loss:0.085, Epoch accuracy:96.77%, Validation loss:1.791, Validation accuracy:60.84%
# Epoch 366: iteration 106/107
# Epoch 366 --- loss:0.039, Epoch accuracy:98.26%, Validation loss:1.818, Validation accuracy:61.77%
# Epoch 367: iteration 106/107
# Epoch 367 --- loss:0.024, Epoch accuracy:99.16%, Validation loss:1.921, Validation accuracy:57.58%
# Epoch 368: iteration 106/107
# Epoch 368 --- loss:0.045, Epoch accuracy:98.14%, Validation loss:1.975, Validation accuracy:60.61%
# Epoch 369: iteration 106/107
# Epoch 369 --- loss:0.030, Epoch accuracy:98.69%, Validation loss:1.871, Validation accuracy:59.91%
# Epoch 370: iteration 106/107
# Epoch 370 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.767, Validation accuracy:63.87%
# Epoch 371: iteration 106/107
# Epoch 371 --- loss:0.023, Epoch accuracy:99.07%, Validation loss:1.804, Validation accuracy:62.24%
# Epoch 372: iteration 106/107
# Epoch 372 --- loss:0.022, Epoch accuracy:99.19%, Validation loss:1.791, Validation accuracy:62.94%
# Epoch 373: iteration 106/107
# Epoch 373 --- loss:0.015, Epoch accuracy:99.36%, Validation loss:1.949, Validation accuracy:60.37%
# Epoch 374: iteration 106/107
# Epoch 374 --- loss:0.016, Epoch accuracy:99.24%, Validation loss:1.743, Validation accuracy:63.40%
# Epoch 375: iteration 106/107
# Epoch 375 --- loss:0.020, Epoch accuracy:99.13%, Validation loss:2.092, Validation accuracy:60.14%
# Epoch 376: iteration 106/107
# Epoch 376 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:1.844, Validation accuracy:59.21%
# Epoch 377: iteration 106/107
# Epoch 377 --- loss:0.026, Epoch accuracy:99.07%, Validation loss:1.965, Validation accuracy:58.97%
# Epoch 378: iteration 106/107
# Epoch 378 --- loss:0.061, Epoch accuracy:97.56%, Validation loss:1.810, Validation accuracy:61.77%
# Epoch 379: iteration 106/107
# Epoch 379 --- loss:0.060, Epoch accuracy:97.56%, Validation loss:1.971, Validation accuracy:60.14%
# Epoch 380: iteration 106/107
# Epoch 380 --- loss:0.021, Epoch accuracy:99.22%, Validation loss:1.958, Validation accuracy:60.84%
# Epoch 381: iteration 106/107
# Epoch 381 --- loss:0.037, Epoch accuracy:98.46%, Validation loss:2.181, Validation accuracy:57.11%
# Epoch 382: iteration 106/107
# Epoch 382 --- loss:0.043, Epoch accuracy:98.29%, Validation loss:1.743, Validation accuracy:62.24%
# Epoch 383: iteration 106/107
# Epoch 383 --- loss:0.018, Epoch accuracy:99.33%, Validation loss:1.893, Validation accuracy:61.77%
# Epoch 384: iteration 106/107
# Epoch 384 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:1.847, Validation accuracy:64.34%
# Epoch 385: iteration 106/107
# Epoch 385 --- loss:0.016, Epoch accuracy:99.30%, Validation loss:1.878, Validation accuracy:60.37%
# Epoch 386: iteration 106/107
# Epoch 386 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.921, Validation accuracy:62.70%
# Epoch 387: iteration 106/107
# Epoch 387 --- loss:0.022, Epoch accuracy:99.13%, Validation loss:2.005, Validation accuracy:59.67%
# Epoch 388: iteration 106/107
# Epoch 388 --- loss:0.045, Epoch accuracy:98.17%, Validation loss:2.079, Validation accuracy:61.07%
# Epoch 389: iteration 106/107
# Epoch 389 --- loss:0.066, Epoch accuracy:97.36%, Validation loss:1.688, Validation accuracy:62.24%
# Epoch 390: iteration 106/107
# Epoch 390 --- loss:0.034, Epoch accuracy:98.55%, Validation loss:2.048, Validation accuracy:59.44%
# Epoch 391: iteration 106/107
# Epoch 391 --- loss:0.040, Epoch accuracy:98.17%, Validation loss:1.838, Validation accuracy:63.40%
# Epoch 392: iteration 106/107
# Epoch 392 --- loss:0.031, Epoch accuracy:98.87%, Validation loss:2.023, Validation accuracy:61.77%
# Epoch 393: iteration 106/107
# Epoch 393 --- loss:0.029, Epoch accuracy:98.84%, Validation loss:1.727, Validation accuracy:64.57%
# Epoch 394: iteration 106/107
# Epoch 394 --- loss:0.032, Epoch accuracy:98.75%, Validation loss:1.820, Validation accuracy:61.77%
# Epoch 395: iteration 106/107
# Epoch 395 --- loss:0.060, Epoch accuracy:97.56%, Validation loss:2.005, Validation accuracy:59.21%
# Epoch 396: iteration 106/107
# Epoch 396 --- loss:0.041, Epoch accuracy:98.49%, Validation loss:1.913, Validation accuracy:61.07%
# Epoch 397: iteration 106/107
# Epoch 397 --- loss:0.028, Epoch accuracy:98.84%, Validation loss:1.885, Validation accuracy:57.58%
# Epoch 398: iteration 106/107
# Epoch 398 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:1.824, Validation accuracy:64.57%
# Epoch 399: iteration 106/107
# Epoch 399 --- loss:0.081, Epoch accuracy:96.98%, Validation loss:2.089, Validation accuracy:61.77%
# Epoch 400: iteration 106/107
# Epoch 400 --- loss:0.067, Epoch accuracy:97.44%, Validation loss:1.732, Validation accuracy:63.87%
# Epoch 401: iteration 106/107
# Epoch 401 --- loss:0.048, Epoch accuracy:98.14%, Validation loss:1.877, Validation accuracy:61.07%
# Epoch 402: iteration 106/107
# Epoch 402 --- loss:0.039, Epoch accuracy:98.52%, Validation loss:1.828, Validation accuracy:60.14%
# Epoch 403: iteration 106/107
# Epoch 403 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:2.041, Validation accuracy:62.00%
# Epoch 404: iteration 106/107
# Epoch 404 --- loss:0.025, Epoch accuracy:99.04%, Validation loss:1.805, Validation accuracy:61.54%
# Epoch 405: iteration 106/107
# Epoch 405 --- loss:0.031, Epoch accuracy:98.75%, Validation loss:1.835, Validation accuracy:60.61%
# Epoch 406: iteration 106/107
# Epoch 406 --- loss:0.016, Epoch accuracy:99.33%, Validation loss:1.816, Validation accuracy:62.94%
# Epoch 407: iteration 106/107
# Epoch 407 --- loss:0.021, Epoch accuracy:99.01%, Validation loss:1.918, Validation accuracy:62.94%
# Epoch 408: iteration 106/107
# Epoch 408 --- loss:0.018, Epoch accuracy:99.16%, Validation loss:1.781, Validation accuracy:62.70%
# Epoch 409: iteration 106/107
# Epoch 409 --- loss:0.014, Epoch accuracy:99.33%, Validation loss:1.818, Validation accuracy:60.61%
# Epoch 410: iteration 106/107
# Epoch 410 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.795, Validation accuracy:63.17%
# Epoch 411: iteration 106/107
# Epoch 411 --- loss:0.009, Epoch accuracy:99.51%, Validation loss:1.771, Validation accuracy:61.77%
# Epoch 412: iteration 106/107
# Epoch 412 --- loss:0.008, Epoch accuracy:99.51%, Validation loss:1.723, Validation accuracy:62.70%
# Epoch 413: iteration 106/107
# Epoch 413 --- loss:0.014, Epoch accuracy:99.30%, Validation loss:1.806, Validation accuracy:61.31%
# Epoch 414: iteration 106/107
# Epoch 414 --- loss:0.031, Epoch accuracy:98.63%, Validation loss:2.356, Validation accuracy:54.55%
# Epoch 415: iteration 106/107
# Epoch 415 --- loss:0.094, Epoch accuracy:96.34%, Validation loss:1.870, Validation accuracy:61.07%
# Epoch 416: iteration 106/107
# Epoch 416 --- loss:0.077, Epoch accuracy:96.95%, Validation loss:1.914, Validation accuracy:62.70%
# Epoch 417: iteration 106/107
# Epoch 417 --- loss:0.034, Epoch accuracy:98.92%, Validation loss:1.796, Validation accuracy:62.24%
# Epoch 418: iteration 106/107
# Epoch 418 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.745, Validation accuracy:60.37%
# Epoch 419: iteration 106/107
# Epoch 419 --- loss:0.020, Epoch accuracy:99.16%, Validation loss:1.805, Validation accuracy:58.97%
# Epoch 420: iteration 106/107
# Epoch 420 --- loss:0.018, Epoch accuracy:99.24%, Validation loss:1.778, Validation accuracy:62.94%
# Epoch 421: iteration 106/107
# Epoch 421 --- loss:0.016, Epoch accuracy:99.24%, Validation loss:1.805, Validation accuracy:63.17%
# Epoch 422: iteration 106/107
# Epoch 422 --- loss:0.022, Epoch accuracy:98.92%, Validation loss:1.770, Validation accuracy:64.80%
# Epoch 423: iteration 106/107
# Epoch 423 --- loss:0.015, Epoch accuracy:99.16%, Validation loss:2.013, Validation accuracy:61.77%
# Epoch 424: iteration 106/107
# Epoch 424 --- loss:0.027, Epoch accuracy:98.78%, Validation loss:1.930, Validation accuracy:63.17%
# Epoch 425: iteration 106/107
# Epoch 425 --- loss:0.038, Epoch accuracy:98.34%, Validation loss:1.962, Validation accuracy:58.51%
# Epoch 426: iteration 106/107
# Epoch 426 --- loss:0.057, Epoch accuracy:97.85%, Validation loss:2.065, Validation accuracy:61.31%
# Epoch 427: iteration 106/107
# Epoch 427 --- loss:0.058, Epoch accuracy:97.65%, Validation loss:1.712, Validation accuracy:63.17%
# Epoch 428: iteration 106/107
# Epoch 428 --- loss:0.018, Epoch accuracy:99.27%, Validation loss:1.869, Validation accuracy:61.54%
# Epoch 429: iteration 106/107
# Epoch 429 --- loss:0.037, Epoch accuracy:98.29%, Validation loss:1.864, Validation accuracy:60.84%
# Epoch 430: iteration 106/107
# Epoch 430 --- loss:0.034, Epoch accuracy:98.63%, Validation loss:1.914, Validation accuracy:56.41%
# Epoch 431: iteration 106/107
# Epoch 431 --- loss:0.037, Epoch accuracy:98.37%, Validation loss:1.847, Validation accuracy:61.31%
# Epoch 432: iteration 106/107
# Epoch 432 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.753, Validation accuracy:61.54%
# Epoch 433: iteration 106/107
# Epoch 433 --- loss:0.019, Epoch accuracy:99.07%, Validation loss:1.861, Validation accuracy:59.44%
# Epoch 434: iteration 106/107
# Epoch 434 --- loss:0.022, Epoch accuracy:99.10%, Validation loss:1.796, Validation accuracy:64.10%
# Epoch 435: iteration 106/107
# Epoch 435 --- loss:0.029, Epoch accuracy:98.66%, Validation loss:1.968, Validation accuracy:60.61%
# Epoch 436: iteration 106/107
# Epoch 436 --- loss:0.037, Epoch accuracy:98.37%, Validation loss:1.721, Validation accuracy:62.47%
# Epoch 437: iteration 106/107
# Epoch 437 --- loss:0.090, Epoch accuracy:96.60%, Validation loss:1.906, Validation accuracy:60.37%
# Epoch 438: iteration 106/107
# Epoch 438 --- loss:0.045, Epoch accuracy:98.20%, Validation loss:1.859, Validation accuracy:60.84%
# Epoch 439: iteration 106/107
# Epoch 439 --- loss:0.028, Epoch accuracy:98.84%, Validation loss:1.894, Validation accuracy:62.00%
# Epoch 440: iteration 106/107
# Epoch 440 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:2.058, Validation accuracy:59.21%
# Epoch 441: iteration 106/107
# Epoch 441 --- loss:0.020, Epoch accuracy:99.16%, Validation loss:1.851, Validation accuracy:63.64%
# Epoch 442: iteration 106/107
# Epoch 442 --- loss:0.027, Epoch accuracy:98.87%, Validation loss:1.851, Validation accuracy:60.61%
# Epoch 443: iteration 106/107
# Epoch 443 --- loss:0.053, Epoch accuracy:97.91%, Validation loss:1.983, Validation accuracy:62.47%
# Epoch 444: iteration 106/107
# Epoch 444 --- loss:0.033, Epoch accuracy:98.58%, Validation loss:2.056, Validation accuracy:60.14%
# Epoch 445: iteration 106/107
# Epoch 445 --- loss:0.062, Epoch accuracy:97.50%, Validation loss:1.796, Validation accuracy:63.64%
# Epoch 446: iteration 106/107
# Epoch 446 --- loss:0.031, Epoch accuracy:98.72%, Validation loss:1.760, Validation accuracy:63.40%
# Epoch 447: iteration 106/107
# Epoch 447 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:1.880, Validation accuracy:62.00%
# Epoch 448: iteration 106/107
# Epoch 448 --- loss:0.023, Epoch accuracy:98.98%, Validation loss:1.861, Validation accuracy:62.47%
# Epoch 449: iteration 106/107
# Epoch 449 --- loss:0.020, Epoch accuracy:99.10%, Validation loss:1.874, Validation accuracy:59.91%
# Epoch 450: iteration 106/107
# Epoch 450 --- loss:0.054, Epoch accuracy:97.53%, Validation loss:2.181, Validation accuracy:59.91%
# Epoch 451: iteration 106/107
# Epoch 451 --- loss:0.038, Epoch accuracy:98.34%, Validation loss:2.104, Validation accuracy:56.41%
# Epoch 452: iteration 106/107
# Epoch 452 --- loss:0.031, Epoch accuracy:98.66%, Validation loss:1.884, Validation accuracy:61.31%
# Epoch 453: iteration 106/107
# Epoch 453 --- loss:0.029, Epoch accuracy:98.78%, Validation loss:1.997, Validation accuracy:59.44%
# Epoch 454: iteration 106/107
# Epoch 454 --- loss:0.034, Epoch accuracy:98.55%, Validation loss:1.876, Validation accuracy:60.61%
# Epoch 455: iteration 106/107
# Epoch 455 --- loss:0.053, Epoch accuracy:98.20%, Validation loss:2.322, Validation accuracy:56.41%
# Epoch 456: iteration 106/107
# Epoch 456 --- loss:0.064, Epoch accuracy:97.59%, Validation loss:1.995, Validation accuracy:58.74%
# Epoch 457: iteration 106/107
# Epoch 457 --- loss:0.034, Epoch accuracy:98.63%, Validation loss:1.827, Validation accuracy:62.24%
# Epoch 458: iteration 106/107
# Epoch 458 --- loss:0.026, Epoch accuracy:98.84%, Validation loss:1.803, Validation accuracy:61.31%
# Epoch 459: iteration 106/107
# Epoch 459 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.896, Validation accuracy:61.54%
# Epoch 460: iteration 106/107
# Epoch 460 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.722, Validation accuracy:61.54%
# Epoch 461: iteration 106/107
# Epoch 461 --- loss:0.015, Epoch accuracy:99.33%, Validation loss:1.804, Validation accuracy:63.17%
# Epoch 462: iteration 106/107
# Epoch 462 --- loss:0.030, Epoch accuracy:98.58%, Validation loss:2.150, Validation accuracy:61.54%
# Epoch 463: iteration 106/107
# Epoch 463 --- loss:0.042, Epoch accuracy:98.37%, Validation loss:1.850, Validation accuracy:62.47%
# Epoch 464: iteration 106/107
# Epoch 464 --- loss:0.055, Epoch accuracy:97.68%, Validation loss:1.878, Validation accuracy:60.61%
# Epoch 465: iteration 106/107
# Epoch 465 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:1.819, Validation accuracy:60.61%
# Epoch 466: iteration 106/107
# Epoch 466 --- loss:0.021, Epoch accuracy:99.22%, Validation loss:1.979, Validation accuracy:60.37%
# Epoch 467: iteration 106/107
# Epoch 467 --- loss:0.017, Epoch accuracy:99.19%, Validation loss:1.925, Validation accuracy:64.34%
# Epoch 468: iteration 106/107
# Epoch 468 --- loss:0.017, Epoch accuracy:99.19%, Validation loss:1.778, Validation accuracy:61.07%
# Epoch 469: iteration 106/107
# Epoch 469 --- loss:0.021, Epoch accuracy:99.07%, Validation loss:1.779, Validation accuracy:61.54%
# Epoch 470: iteration 106/107
# Epoch 470 --- loss:0.012, Epoch accuracy:99.45%, Validation loss:1.827, Validation accuracy:62.00%
# Epoch 471: iteration 106/107
# Epoch 471 --- loss:0.013, Epoch accuracy:99.39%, Validation loss:1.778, Validation accuracy:61.54%
# Epoch 472: iteration 106/107
# Epoch 472 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.919, Validation accuracy:63.40%
# Epoch 473: iteration 106/107
# Epoch 473 --- loss:0.010, Epoch accuracy:99.45%, Validation loss:1.803, Validation accuracy:61.54%
# Epoch 474: iteration 106/107
# Epoch 474 --- loss:0.010, Epoch accuracy:99.45%, Validation loss:1.739, Validation accuracy:62.24%
# Epoch 475: iteration 106/107
# Epoch 475 --- loss:0.022, Epoch accuracy:99.10%, Validation loss:2.056, Validation accuracy:59.21%
# Epoch 476: iteration 106/107
# Epoch 476 --- loss:0.027, Epoch accuracy:99.04%, Validation loss:1.746, Validation accuracy:64.34%
# Epoch 477: iteration 106/107
# Epoch 477 --- loss:0.014, Epoch accuracy:99.30%, Validation loss:1.962, Validation accuracy:62.24%
# Epoch 478: iteration 106/107
# Epoch 478 --- loss:0.046, Epoch accuracy:98.23%, Validation loss:1.912, Validation accuracy:61.77%
# Epoch 479: iteration 106/107
# Epoch 479 --- loss:0.068, Epoch accuracy:97.12%, Validation loss:2.126, Validation accuracy:60.37%
# Epoch 480: iteration 106/107
# Epoch 480 --- loss:0.061, Epoch accuracy:97.73%, Validation loss:1.962, Validation accuracy:60.61%
# Epoch 481: iteration 106/107
# Epoch 481 --- loss:0.022, Epoch accuracy:99.10%, Validation loss:1.885, Validation accuracy:61.77%
# Epoch 482: iteration 106/107
# Epoch 482 --- loss:0.024, Epoch accuracy:99.13%, Validation loss:1.808, Validation accuracy:63.17%
# Epoch 483: iteration 106/107
# Epoch 483 --- loss:0.026, Epoch accuracy:98.95%, Validation loss:1.900, Validation accuracy:59.44%
# Epoch 484: iteration 106/107
# Epoch 484 --- loss:0.064, Epoch accuracy:97.36%, Validation loss:1.930, Validation accuracy:61.31%
# Epoch 485: iteration 106/107
# Epoch 485 --- loss:0.038, Epoch accuracy:98.52%, Validation loss:1.876, Validation accuracy:61.31%
# Epoch 486: iteration 106/107
# Epoch 486 --- loss:0.036, Epoch accuracy:98.52%, Validation loss:1.739, Validation accuracy:62.94%
# Epoch 487: iteration 106/107
# Epoch 487 --- loss:0.024, Epoch accuracy:98.84%, Validation loss:1.830, Validation accuracy:61.31%
# Epoch 488: iteration 106/107
# Epoch 488 --- loss:0.025, Epoch accuracy:98.95%, Validation loss:1.776, Validation accuracy:63.40%
# Epoch 489: iteration 106/107
# Epoch 489 --- loss:0.048, Epoch accuracy:98.23%, Validation loss:1.800, Validation accuracy:61.07%
# Epoch 490: iteration 106/107
# Epoch 490 --- loss:0.018, Epoch accuracy:99.27%, Validation loss:1.797, Validation accuracy:62.00%
# Epoch 491: iteration 106/107
# Epoch 491 --- loss:0.013, Epoch accuracy:99.27%, Validation loss:1.696, Validation accuracy:63.40%
# Epoch 492: iteration 106/107
# Epoch 492 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:1.836, Validation accuracy:64.10%
# Epoch 493: iteration 106/107
# Epoch 493 --- loss:0.024, Epoch accuracy:98.95%, Validation loss:1.830, Validation accuracy:61.31%
# Epoch 494: iteration 106/107
# Epoch 494 --- loss:0.052, Epoch accuracy:97.65%, Validation loss:2.036, Validation accuracy:59.21%
# Epoch 495: iteration 106/107
# Epoch 495 --- loss:0.044, Epoch accuracy:98.34%, Validation loss:2.010, Validation accuracy:57.34%
# Epoch 496: iteration 106/107
# Epoch 496 --- loss:0.038, Epoch accuracy:98.49%, Validation loss:1.946, Validation accuracy:59.67%
# Epoch 497: iteration 106/107
# Epoch 497 --- loss:0.015, Epoch accuracy:99.39%, Validation loss:1.894, Validation accuracy:61.07%
# Epoch 498: iteration 106/107
# Epoch 498 --- loss:0.060, Epoch accuracy:97.50%, Validation loss:1.998, Validation accuracy:60.14%
# Epoch 499: iteration 106/107
# Epoch 499 --- loss:0.040, Epoch accuracy:98.17%, Validation loss:1.929, Validation accuracy:59.44%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = './models/checkpoints/'  

# pick the epoch to load
epoch = '499'
model_name = f'parallel_all_you_want-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict)).to(device)
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from ./models/checkpoints/parallel_all_you_want-499.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 63.78%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
